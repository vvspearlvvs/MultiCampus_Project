# %%
import pandas as pd
import numpy as np
import seaborn as sns

# %%
#그래프 패키지 
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
# 한글 문제 해결
import platform

from matplotlib import font_manager, rc
plt.rcParams['axes.unicode_minus'] = False

if platform.system() == 'Darwin':  # 맥OS 
    rc('font', family='AppleGothic')
elif platform.system() == 'Windows':  # 윈도우
    path = "c:/Windows/Fonts/malgun.ttf"
    font_name = font_manager.FontProperties(fname=path).get_name()
    rc('font', family=font_name)
else:
    print('Unknown system...  sorry~~~')

# %%
# 동시 출력
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity="all"

# %% [markdown]
# ## 19/ 20 / 21 데이터 정리

# %%
raw_data_2019 = pd.read_csv("./data/KOBIS_총_관객수_및_매출액_월별_2019.csv", encoding='UTF-8')
raw_data_2020 = pd.read_csv("./data/KOBIS_총_관객수_및_매출액_월별_2020.csv", encoding='UTF-8')
raw_data_2021 = pd.read_csv("./data/KOBIS_총_관객수_및_매출액_월별_2021.csv", encoding='UTF-8')

# %%
raw_data_2019.head()
raw_data_2020.head()
raw_data_2020.tail()
# Out:
#                                ■ 총 관객수 및 매출액_월별 Unnamed: 1 Unnamed: 2  \
# 0                             - 조회일: 2021-08-12        NaN        NaN
# 1  - 출처: 영화진흥위원회 통합전산망 (http://www.kobis.or.kr)        NaN        NaN
# 2                        ▶ 검색조건 [ 조회기간 : 2019 ]        NaN        NaN
# 3                                            년월         한국        NaN
# 4                                           NaN       개봉편수       상영편수
#
#   Unnamed: 3 Unnamed: 4 Unnamed: 5 Unnamed: 6 Unnamed: 7 Unnamed: 8  \
# 0        NaN        NaN        NaN        NaN        NaN        NaN
# 1        NaN        NaN        NaN        NaN        NaN        NaN
# 2        NaN        NaN        NaN        NaN        NaN        NaN
# 3        NaN        NaN        NaN         외국        NaN        NaN
# 4        매출액        관객수        점유율       개봉편수       상영편수        매출액
#
#   Unnamed: 9 Unnamed: 10 Unnamed: 11 Unnamed: 12 Unnamed: 13 Unnamed: 14
# ...

# %%
## 불필요한 행 제거
raw_data_2019.drop([0], inplace=True)
raw_data_2019.drop([1], inplace=True)
raw_data_2019.drop([2], inplace=True)
raw_data_2020.drop([0], inplace=True)
raw_data_2020.drop([1], inplace=True)
raw_data_2020.drop([2], inplace=True)
raw_data_2021.drop([0], inplace=True)
raw_data_2021.drop([1], inplace=True)
raw_data_2021.drop([2], inplace=True)

# %%
raw_data_2019.head()
raw_data_2020.head()
raw_data_2021.head()
# Out:
#   ■ 총 관객수 및 매출액_월별 Unnamed: 1 Unnamed: 2       Unnamed: 3  Unnamed: 4  \
# 3               년월         한국        NaN              NaN         NaN
# 4              NaN       개봉편수       상영편수              매출액         관객수
# 5          2019-01         46        130   99,614,450,357  11,950,823
# 6          2019-02         33        109  146,336,183,090  17,228,752
# 7          2019-03         46        136   53,449,954,665   6,267,605
#
#   Unnamed: 5 Unnamed: 6 Unnamed: 7      Unnamed: 8 Unnamed: 9 Unnamed: 10  \
# 3        NaN         외국        NaN             NaN        NaN         NaN
# 4        점유율       개봉편수       상영편수             매출액        관객수         점유율
# 5      65.9%        101        239  51,547,027,839  6,171,620       34.1%
# 6      77.3%         81        209  43,654,624,880  5,048,981       22.7%
# 7      42.7%         96        239  73,109,062,784  8,404,088       57.3%
#
#   Unnamed: 11 Unnamed: 12      Unnamed: 13 Unnamed: 14
# ...

# %%
##불필요한 열 제거
raw_data_2019.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 
                    'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1, inplace=True)
raw_data_2020.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 
                    'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1, inplace=True)
raw_data_2021.drop(['Unnamed: 1', 'Unnamed: 2', 'Unnamed: 3', 'Unnamed: 4', 'Unnamed: 5', 
                    'Unnamed: 6', 'Unnamed: 7', 'Unnamed: 8', 'Unnamed: 9', 'Unnamed: 10'], axis=1, inplace=True)

# %%
raw_data_2019.head()
raw_data_2020.head()
raw_data_2021.head()
# Out:
#   ■ 총 관객수 및 매출액_월별 Unnamed: 11 Unnamed: 12      Unnamed: 13 Unnamed: 14
# 3               년월          전체         NaN              NaN         NaN
# 4              NaN        개봉편수        상영편수              매출액         관객수
# 5          2019-01         147         369  151,161,478,196  18,122,443
# 6          2019-02         114         318  189,990,807,970  22,277,733
# 7          2019-03         142         375  126,559,017,449  14,671,693
#   ■ 총 관객수 및 매출액_월별 Unnamed: 11 Unnamed: 12      Unnamed: 13 Unnamed: 14
# 3               년월          전체         NaN              NaN         NaN
# 4              NaN        개봉편수        상영편수              매출액         관객수
# 5          2020-01         165         406  143,681,061,430  16,843,695
# 6          2020-02         150         370   62,303,647,980   7,372,370
# 7          2020-03         154         344   15,152,718,950   1,834,722
#   ■ 총 관객수 및 매출액_월별 Unnamed: 11 Unnamed: 12     Unnamed: 13 Unnamed: 14
# ...

# %%
# 불필요한 행 제거
raw_data_2019.drop([3], inplace=True)
raw_data_2019.drop([4], inplace=True)
raw_data_2020.drop([3], inplace=True)
raw_data_2020.drop([4], inplace=True)
raw_data_2021.drop([3], inplace=True)
raw_data_2021.drop([4], inplace=True)

# %%
raw_data_2019.head()
raw_data_2020.head()
raw_data_2021.head()
# Out:
#   ■ 총 관객수 및 매출액_월별 Unnamed: 11 Unnamed: 12      Unnamed: 13 Unnamed: 14
# 5          2019-01         147         369  151,161,478,196  18,122,443
# 6          2019-02         114         318  189,990,807,970  22,277,733
# 7          2019-03         142         375  126,559,017,449  14,671,693
# 8          2019-04         155         436  113,184,664,392  13,338,962
# 9          2019-05         152         458  154,563,004,957  18,062,457
#   ■ 총 관객수 및 매출액_월별 Unnamed: 11 Unnamed: 12      Unnamed: 13 Unnamed: 14
# 5          2020-01         165         406  143,681,061,430  16,843,695
# 6          2020-02         150         370   62,303,647,980   7,372,370
# 7          2020-03         154         344   15,152,718,950   1,834,722
# 8          2020-04         180         429    7,515,666,040     972,572
# 9          2020-05         157         436   12,393,715,040   1,526,236
#   ■ 총 관객수 및 매출액_월별 Unnamed: 11 Unnamed: 12     Unnamed: 13 Unnamed: 14
# ...

# %%
## 컬럼 이름 변경
raw_data_2019.rename({'■ 총 관객수 및 매출액_월별':'연도월별', 'Unnamed: 11':'개봉편수', 'Unnamed: 12':'상영편수', 
                     'Unnamed: 13':'매출액', 'Unnamed: 14':'관객수'}, axis='columns', inplace=True)
raw_data_2020.rename({'■ 총 관객수 및 매출액_월별':'연도월별', 'Unnamed: 11':'개봉편수', 'Unnamed: 12':'상영편수', 
                     'Unnamed: 13':'매출액', 'Unnamed: 14':'관객수'}, axis='columns', inplace=True)
raw_data_2021.rename({'■ 총 관객수 및 매출액_월별':'연도월별', 'Unnamed: 11':'개봉편수', 'Unnamed: 12':'상영편수', 
                     'Unnamed: 13':'매출액', 'Unnamed: 14':'관객수'}, axis='columns', inplace=True)

# %%
# 인덱스 변경
raw_data_2019.set_index('연도월별', inplace=True)
raw_data_2020.set_index('연도월별', inplace=True)
raw_data_2021.set_index('연도월별', inplace=True)

# %%
raw_data_2019.head()
raw_data_2020.head()
raw_data_2021.head()
# Out:
#         개봉편수 상영편수              매출액         관객수
# 연도월별
# 2019-01  147  369  151,161,478,196  18,122,443
# 2019-02  114  318  189,990,807,970  22,277,733
# 2019-03  142  375  126,559,017,449  14,671,693
# 2019-04  155  436  113,184,664,392  13,338,962
# 2019-05  152  458  154,563,004,957  18,062,457
#         개봉편수 상영편수              매출액         관객수
# 연도월별
# 2020-01  165  406  143,681,061,430  16,843,695
# 2020-02  150  370   62,303,647,980   7,372,370
# 2020-03  154  344   15,152,718,950   1,834,722
# 2020-04  180  429    7,515,666,040     972,572
# 2020-05  157  436   12,393,715,040   1,526,236
#         개봉편수 상영편수             매출액        관객수
# 연도월별
# 2021-01  130  379  15,793,377,040  1,786,117
# 2021-02  149  382  28,738,934,810  3,111,920
# 2021-03  203  444  30,158,665,300  3,256,510
# 2021-04  189  475  23,544,305,690  2,562,393
# 2021-05  148  424  41,084,306,050  4,380,129

# %%
# 불필요한 합계 행 제거
raw_data_2019.drop(['합계'], inplace=True)
raw_data_2020.drop(['합계'], inplace=True)
raw_data_2021.drop(['합계'], inplace=True)

# %%
raw_data_2019.tail()
raw_data_2020.tail()
raw_data_2021.tail()
# Out:
#         개봉편수 상영편수              매출액         관객수
# 연도월별
# 2019-08  181  436  208,958,173,044  24,786,121
# 2019-09  166  425  124,445,262,708  14,733,642
# 2019-10  215  504  123,754,715,700  14,858,383
# 2019-11  174  596  155,388,033,415  18,600,679
# 2019-12  186  566  186,644,820,812  22,464,620
#         개봉편수 상영편수             매출액        관객수
# 연도월별
# 2020-08  144  431  77,214,053,539  8,834,741
# 2020-09  158  408  26,032,000,372  2,988,680
# 2020-10  170  478  41,527,927,390  4,633,636
# 2020-11  157  578  32,150,120,750  3,595,334
# 2020-12  156  435  12,404,343,250  1,438,873
#         개봉편수 상영편수             매출액        관객수
# 연도월별
# 2021-04  189  475  23,544,305,690  2,562,393
# 2021-05  148  424  41,084,306,050  4,380,129
# 2021-06  153  404  47,026,601,590  4,927,993
# 2021-07  154  389  68,342,176,980  6,976,519
# 2021-08   24  165  26,247,905,660  2,707,685

# %%
raw_data_2019.to_csv("./data/2019_영화관.csv")
raw_data_2020.to_csv("./data/2020_영화관.csv")
raw_data_2021.to_csv("./data/2021_영화관.csv")

# %%
data_2019 = pd.read_csv("./data/2019_영화관.csv", thousands=',', encoding='UTF-8')
data_2020 = pd.read_csv("./data/2020_영화관.csv", thousands=',', encoding='UTF-8')
data_2021 = pd.read_csv("./data/2021_영화관.csv", thousands=',', encoding='UTF-8')

# %% [markdown]
# ## 연도월별 분리 작업

# %%
## split 이후 분리 작업

##2019년
temp_y = []
temp_m = []

for i in range(len(data_2019['연도월별'])):
    temp_y.append(data_2019['연도월별'][i].split('-')[0])
    temp_m.append(data_2019['연도월별'][i].split('-')[1])

    
data_2019['연도'] = temp_y
data_2019['월별'] = temp_m

##2020년

temp_y = []
temp_m = []

for i in range(len(data_2020['연도월별'])):
    temp_y.append(data_2020['연도월별'][i].split('-')[0])
    temp_m.append(data_2020['연도월별'][i].split('-')[1])

    
data_2020['연도'] = temp_y
data_2020['월별'] = temp_m

##2021년
temp_y = []
temp_m = []

for i in range(len(data_2021['연도월별'])):
    temp_y.append(data_2021['연도월별'][i].split('-')[0])
    temp_m.append(data_2021['연도월별'][i].split('-')[1])

    
data_2021['연도'] = temp_y
data_2021['월별'] = temp_m

# %%
# 연도월별 열 제거 (분리)
data_2019.drop(['연도월별'], axis=1, inplace=True)
data_2020.drop(['연도월별'], axis=1, inplace=True)
data_2021.drop(['연도월별'], axis=1, inplace=True)

# %%
data_2019 = data_2019[['연도','월별','개봉편수','상영편수','관객수','매출액']]
data_2020 = data_2020[['연도','월별','개봉편수','상영편수','관객수','매출액']]
data_2021 = data_2021[['연도','월별','개봉편수','상영편수','관객수','매출액']]

# %%
data_2019.head()
data_2020.head()
data_2021.head()
# Out:
#      연도  월별  개봉편수  상영편수       관객수           매출액
# 0  2019  01   147   369  18122443  151161478196
# 1  2019  02   114   318  22277733  189990807970
# 2  2019  03   142   375  14671693  126559017449
# 3  2019  04   155   436  13338962  113184664392
# 4  2019  05   152   458  18062457  154563004957
#      연도  월별  개봉편수  상영편수       관객수           매출액
# 0  2020  01   165   406  16843695  143681061430
# 1  2020  02   150   370   7372370   62303647980
# 2  2020  03   154   344   1834722   15152718950
# 3  2020  04   180   429    972572    7515666040
# 4  2020  05   157   436   1526236   12393715040
#      연도  월별  개봉편수  상영편수      관객수          매출액
# 0  2021  01   130   379  1786117  15793377040
# 1  2021  02   149   382  3111920  28738934810
# 2  2021  03   203   444  3256510  30158665300
# 3  2021  04   189   475  2562393  23544305690
# 4  2021  05   148   424  4380129  41084306050

# %%
tot_data = pd.concat([data_2020,data_2021])

# %%
tot_data
# Out:
#       연도  월별  개봉편수  상영편수       관객수           매출액
# 0   2020  01   165   406  16843695  143681061430
# 1   2020  02   150   370   7372370   62303647980
# 2   2020  03   154   344   1834722   15152718950
# 3   2020  04   180   429    972572    7515666040
# 4   2020  05   157   436   1526236   12393715040
# 5   2020  06   136   417   3864533   32760133800
# 6   2020  07   170   484   5618701   47239833650
# 7   2020  08   144   431   8834741   77214053539
# 8   2020  09   158   408   2988680   26032000372
# 9   2020  10   170   478   4633636   41527927390
# 10  2020  11   157   578   3595334   32150120750
# 11  2020  12   156   435   1438873   12404343250
# 0   2021  01   130   379   1786117   15793377040
# 1   2021  02   149   382   3111920   28738934810
# 2   2021  03   203   444   3256510   30158665300
# 3   2021  04   189   475   2562393   23544305690
# 4   2021  05   148   424   4380129   41084306050
# 5   2021  06   153   404   4927993   47026601590
# ...

# %%
movies = tot_data.sort_values(by = ['월별','연도', '개봉편수'])
sns.catplot(data = movies, x='월별', y='개봉편수', hue = '연도', kind = 'bar', palette = 'Greens', legend_out = False)

movies_2019 = data_2019.sort_values(by = ['월별','연도', '개봉편수'])
sns.lineplot(data = movies_2019, x='월별', y='개봉편수', hue = '연도')

plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# <AxesSubplot:xlabel='월별', ylabel='개봉편수'>

# %%
movies = tot_data.sort_values(by = ['월별', '연도', '상영편수'])
sns.catplot(data = movies, x='월별', y='상영편수', hue = '연도', kind = 'bar', palette = 'Reds', legend_out = False)

movies_2019 = data_2019.sort_values(by = ['월별','연도', '상영편수'])
sns.lineplot(data = movies_2019, x='월별', y='상영편수', hue = '연도')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# <AxesSubplot:xlabel='월별', ylabel='상영편수'>

# %%
movies_2019
# Out:
#       연도  월별  개봉편수  상영편수       관객수           매출액
# 0   2019  01   147   369  18122443  151161478196
# 1   2019  02   114   318  22277733  189990807970
# 2   2019  03   142   375  14671693  126559017449
# 3   2019  04   155   436  13338962  113184664392
# 4   2019  05   152   458  18062457  154563004957
# 5   2019  06   153   457  22845579  195237798708
# 6   2019  07   158   424  21916465  184101302717
# 7   2019  08   181   436  24786121  208958173044
# 8   2019  09   166   425  14733642  124445262708
# 9   2019  10   215   504  14858383  123754715700
# 10  2019  11   174   596  18600679  155388033415
# 11  2019  12   186   566  22464620  186644820812

# %%
movies = tot_data.sort_values(by = ['월별', '연도', '관객수'])
sns.catplot(data = movies, x='월별', y='관객수', hue = '연도', kind = 'bar', palette = 'Reds', legend_out = False)

movies_2019 = data_2019.sort_values(by = ['월별','연도', '관객수'])
sns.lineplot(data = movies_2019, x='월별', y='관객수', hue = '연도')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))

## y축
plt.ylabel("관객수 (단위 : 만 명)")
#y = ['0', '5000000', '10000000', '15000000', '20000000', '25000000']
#plt.yticks(y)
# Out:
# <AxesSubplot:xlabel='월별', ylabel='관객수'>
# Text(6.799999999999997, 0.5, '관객수 (단위 : 만 명)')

# %%
movies = tot_data.sort_values(by = ['월별', '연도', '매출액'])
sns.catplot(data = movies, x='월별', y='매출액', hue = '연도', kind = 'bar', palette = 'Reds', legend_out = False)

movies_2019 = data_2019.sort_values(by = ['월별','연도', '매출액'])
sns.lineplot(data = movies_2019, x='월별', y='매출액', hue = '연도')
plt.legend(loc='center left', bbox_to_anchor=(1, 0.5))
# Out:
# <AxesSubplot:xlabel='월별', ylabel='매출액'>

# %% [markdown]
# ## 그래프 시각화

# %%
plt.figure(figsize=(10,20))
months = ['01월','02월','03월','04월','05월','06월','07월','08월','09월','10월','11월','12월']
plt.plot(months, data_2019['개봉편수'], color='green')
plt.plot(months, data_2020['개봉편수'], color='red')

# %%
plt.figure(figsize=(10,20))
months = ['01월','02월','03월','04월','05월','06월','07월','08월','09월','10월','11월','12월']
plt.plot(months, data_2019['개봉편수'], color='green')
plt.plot(months, data_2020['개봉편수'], color='red')
plt.plot(months, data_2021['개봉편수'], color='blue')
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-113-1b7d3294c89f> in <module>
#       3 plt.plot(months, data_2019['개봉편수'], color='green')
#       4 plt.plot(months, data_2020['개봉편수'], color='red')
# ----> 5 plt.plot(months, data_2021['개봉편수'], color='blue')
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in plot(scalex, scaley, data, *args, **kwargs)
#    2838 @_copy_docstring_and_deprecators(Axes.plot)
#    2839 def plot(*args, scalex=True, scaley=True, data=None, **kwargs):
# -> 2840     return gca().plot(
#    2841         *args, scalex=scalex, scaley=scaley,
#    2842         **({"data": data} if data is not None else {}), **kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1741         """
# ...
