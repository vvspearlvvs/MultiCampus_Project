# %%
import pandas as pd

# %%
train = pd.read_excel('철도이용객data1.xls')

# %%
train.reset_index()
# Out:
#     index   Unnamed: 0                                Unnamed: 1 Unnamed: 2  \
# 0       0          NaN                                       NaN        NaN
# 1       1          NaN                                   201901월    201902월
# 2       2   고속철도 여객수 계                                     6,929      6,942
# 3       3       KTX이용률                                        86         96
# 4       4       SRT이용률                                       113        116
# 5       5   경부선 KTX여객수                                     2,822      2,857
# 6       6   경부선 KTX이용률                                        89         98
# 7       7   경부선 SRT여객수                                     1,366      1,297
# 8       8   경부선 SRT이용률                                       121        123
# 9       9   호남선 KTX여객수                                       805        848
# 10     10   호남선 KTX이용률                                        68         79
# ...

# %%
train.drop([0,19])
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1           NaN    201901월    201902월    201903월    201904월    201905월
# 2    고속철도 여객수 계      6,929      6,942      7,188      7,247      7,733
# 3        KTX이용률         86         96         90         95         98
# 4        SRT이용률        113        116        113        117        119
# 5    경부선 KTX여객수      2,822      2,857      2,906      2,951      3,148
# 6    경부선 KTX이용률         89         98         91         97         99
# 7    경부선 SRT여객수      1,366      1,297      1,403      1,372      1,446
# 8    경부선 SRT이용률        121        123        121        125        127
# 9    호남선 KTX여객수        805        848        865        887        955
# 10   호남선 KTX이용률         68         79         74         79         82
# 11   호남선 SRT여객수        488        461        493        497        526
# 12   호남선 SRT이용률         95        100         96        101        103
# ...

# %%
train.loc[1][0]="월별"

# %%
train.drop([0,19])
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1            월별    201901월    201902월    201903월    201904월    201905월
# 2    고속철도 여객수 계      6,929      6,942      7,188      7,247      7,733
# 3        KTX이용률         86         96         90         95         98
# 4        SRT이용률        113        116        113        117        119
# 5    경부선 KTX여객수      2,822      2,857      2,906      2,951      3,148
# 6    경부선 KTX이용률         89         98         91         97         99
# 7    경부선 SRT여객수      1,366      1,297      1,403      1,372      1,446
# 8    경부선 SRT이용률        121        123        121        125        127
# 9    호남선 KTX여객수        805        848        865        887        955
# 10   호남선 KTX이용률         68         79         74         79         82
# 11   호남선 SRT여객수        488        461        493        497        526
# 12   호남선 SRT이용률         95        100         96        101        103
# ...

# %%
train = train.drop([0,19])

# %%
train.head()
# Out:
#    Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1          월별    201901월    201902월    201903월    201904월    201905월
# 2  고속철도 여객수 계      6,929      6,942      7,188      7,247      7,733
# 3      KTX이용률         86         96         90         95         98
# 4      SRT이용률        113        116        113        117        119
# 5  경부선 KTX여객수      2,822      2,857      2,906      2,951      3,148
#
#   Unnamed: 6 Unnamed: 7 Unnamed: 8 Unnamed: 9  ... Unnamed: 20 Unnamed: 21  \
# 1    201906월    201907월    201908월    201909월  ...     202008월     202009월
# 2      7,294      7,290      7,656      7,379  ...       5,186       3,812
# 3         94         93         96         95  ...          63          46
# 4        118        117        119        117  ...          92          74
# 5      2,943      2,929      3,088      2,931  ...       1,948       1,370
#
#   Unnamed: 22 Unnamed: 23 Unnamed: 24 Unnamed: 25 Unnamed: 26 Unnamed: 27  \
# ...

# %%
train.to_csv('철도data.csv')

# %%
train
# Out:
#      Unnamed: 0 Unnamed: 1 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1            월별    201901월    201902월    201903월    201904월    201905월
# 2    고속철도 여객수 계      6,929      6,942      7,188      7,247      7,733
# 3        KTX이용률         86         96         90         95         98
# 4        SRT이용률        113        116        113        117        119
# 5    경부선 KTX여객수      2,822      2,857      2,906      2,951      3,148
# 6    경부선 KTX이용률         89         98         91         97         99
# 7    경부선 SRT여객수      1,366      1,297      1,403      1,372      1,446
# 8    경부선 SRT이용률        121        123        121        125        127
# 9    호남선 KTX여객수        805        848        865        887        955
# 10   호남선 KTX이용률         68         79         74         79         82
# 11   호남선 SRT여객수        488        461        493        497        526
# 12   호남선 SRT이용률         95        100         96        101        103
# ...

# %%
train = train.transpose()

# %%
train.head()
# Out:
#                  1           2       3       4           5           6   \
# Unnamed: 0       월별  고속철도 여객수 계  KTX이용률  SRT이용률  경부선 KTX여객수  경부선 KTX이용률
# Unnamed: 1  201901월       6,929      86     113       2,822          89
# Unnamed: 2  201902월       6,942      96     116       2,857          98
# Unnamed: 3  201903월       7,188      90     113       2,906          91
# Unnamed: 4  201904월       7,247      95     117       2,951          97
#
#                     7           8           9           10          11  \
# Unnamed: 0  경부선 SRT여객수  경부선 SRT이용률  호남선 KTX여객수  호남선 KTX이용률  호남선 SRT여객수
# Unnamed: 1       1,366         121         805          68         488
# Unnamed: 2       1,297         123         848          79         461
# Unnamed: 3       1,403         121         865          74         493
# Unnamed: 4       1,372         125         887          79         497
#
#                     12          13           14          15          16  \
# ...

# %%
train = train.reset_index(drop=True)

# %%
train.transpose()
# Out:
#               0        1        2        3        4
# 1            월별  201901월  201902월  201903월  201904월
# 2    고속철도 여객수 계    6,929    6,942    7,188    7,247
# 3        KTX이용률       86       96       90       95
# 4        SRT이용률      113      116      113      117
# 5    경부선 KTX여객수    2,822    2,857    2,906    2,951
# 6    경부선 KTX이용률       89       98       91       97
# 7    경부선 SRT여객수    1,366    1,297    1,403    1,372
# 8    경부선 SRT이용률      121      123      121      125
# 9    호남선 KTX여객수      805      848      865      887
# 10   호남선 KTX이용률       68       79       74       79
# 11   호남선 SRT여객수      488      461      493      497
# 12   호남선 SRT이용률       95      100       96      101
# 13   경전선 KTX여객수      499      506      535      543
# 14  경전선  KTX이용률       97      107      103      109
# 15   전라선 KTX여객수      533      550      561      568
# 16   전라선 KTX이용률       93      104       97      102
# 17   동해선 KTX여객수      416      423      425      429
# ...
