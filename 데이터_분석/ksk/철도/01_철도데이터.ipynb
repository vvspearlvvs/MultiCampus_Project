# %%
import pandas as pd
import numpy as np

# %%
train = pd.read_excel('철도이용객data.xls')
train
# Out:
#           통계표명:                              고속철도 여객 수송동향 Unnamed: 2  \
# 0           단위:                                     천명, %        NaN
# 1           NaN                                   201901월    201902월
# 2    고속철도 여객수 계                                     6,929      6,942
# 3        KTX이용률                                        86         96
# 4        SRT이용률                                       113        116
# 5    경부선 KTX여객수                                     2,822      2,857
# 6    경부선 KTX이용률                                        89         98
# 7    경부선 SRT여객수                                     1,366      1,297
# 8    경부선 SRT이용률                                       121        123
# 9    호남선 KTX여객수                                       805        848
# 10   호남선 KTX이용률                                        68         79
# 11   호남선 SRT여객수                                       488        461
# 12   호남선 SRT이용률                                        95        100
# ...

# %%
train.reset_index()
# Out:
#     index        통계표명:                              고속철도 여객 수송동향 Unnamed: 2  \
# 0       0          단위:                                     천명, %        NaN
# 1       1          NaN                                   201901월    201902월
# 2       2   고속철도 여객수 계                                     6,929      6,942
# 3       3       KTX이용률                                        86         96
# 4       4       SRT이용률                                       113        116
# 5       5   경부선 KTX여객수                                     2,822      2,857
# 6       6   경부선 KTX이용률                                        89         98
# 7       7   경부선 SRT여객수                                     1,366      1,297
# 8       8   경부선 SRT이용률                                       121        123
# 9       9   호남선 KTX여객수                                       805        848
# 10     10   호남선 KTX이용률                                        68         79
# ...

# %%
train.drop([0,19])
# Out:
#           통계표명: 고속철도 여객 수송동향 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1           NaN      201901월    201902월    201903월    201904월    201905월
# 2    고속철도 여객수 계        6,929      6,942      7,188      7,247      7,733
# 3        KTX이용률           86         96         90         95         98
# 4        SRT이용률          113        116        113        117        119
# 5    경부선 KTX여객수        2,822      2,857      2,906      2,951      3,148
# 6    경부선 KTX이용률           89         98         91         97         99
# 7    경부선 SRT여객수        1,366      1,297      1,403      1,372      1,446
# 8    경부선 SRT이용률          121        123        121        125        127
# 9    호남선 KTX여객수          805        848        865        887        955
# 10   호남선 KTX이용률           68         79         74         79         82
# 11   호남선 SRT여객수          488        461        493        497        526
# 12   호남선 SRT이용률           95        100         96        101        103
# ...

# %%
train.loc[1][0]='월별'

# %%
train.drop([0,19])
# Out:
#           통계표명: 고속철도 여객 수송동향 Unnamed: 2 Unnamed: 3 Unnamed: 4 Unnamed: 5  \
# 1            월별      201901월    201902월    201903월    201904월    201905월
# 2    고속철도 여객수 계        6,929      6,942      7,188      7,247      7,733
# 3        KTX이용률           86         96         90         95         98
# 4        SRT이용률          113        116        113        117        119
# 5    경부선 KTX여객수        2,822      2,857      2,906      2,951      3,148
# 6    경부선 KTX이용률           89         98         91         97         99
# 7    경부선 SRT여객수        1,366      1,297      1,403      1,372      1,446
# 8    경부선 SRT이용률          121        123        121        125        127
# 9    호남선 KTX여객수          805        848        865        887        955
# 10   호남선 KTX이용률           68         79         74         79         82
# 11   호남선 SRT여객수          488        461        493        497        526
# 12   호남선 SRT이용률           95        100         96        101        103
# ...

# %%
train.transpose()
# Out:
#                  0        1           2       3       4           5   \
# 통계표명:           단위:       월별  고속철도 여객수 계  KTX이용률  SRT이용률  경부선 KTX여객수
# 고속철도 여객 수송동향  천명, %  201901월       6,929      86     113       2,822
# Unnamed: 2      NaN  201902월       6,942      96     116       2,857
# Unnamed: 3      NaN  201903월       7,188      90     113       2,906
# Unnamed: 4      NaN  201904월       7,247      95     117       2,951
# Unnamed: 5      NaN  201905월       7,733      98     119       3,148
# Unnamed: 6      NaN  201906월       7,294      94     118       2,943
# Unnamed: 7      NaN  201907월       7,290      93     117       2,929
# Unnamed: 8      NaN  201908월       7,656      96     119       3,088
# Unnamed: 9      NaN  201909월       7,379      95     117       2,931
# Unnamed: 10     NaN  201910월       7,819      98     125       3,095
# Unnamed: 11     NaN  201911월       7,873     107     129       3,106
# Unnamed: 12     NaN  201912월       8,070     101     126       3,228
# ...

# %%
train = train.reset_index(drop=True)

# %%
train = train.drop([0,19])

# %%
train = train.transpose()

# %%
train = train.reset_index(drop=True)

# %%
train.to_excel('철도데이터.xls')

# %%
train.transpose()
# Out:
#              0        1        2        3        4        5        6   \
# 1            월별  201901월  201902월  201903월  201904월  201905월  201906월
# 2    고속철도 여객수 계    6,929    6,942    7,188    7,247    7,733    7,294
# 3        KTX이용률       86       96       90       95       98       94
# 4        SRT이용률      113      116      113      117      119      118
# 5    경부선 KTX여객수    2,822    2,857    2,906    2,951    3,148    2,943
# 6    경부선 KTX이용률       89       98       91       97       99       95
# 7    경부선 SRT여객수    1,366    1,297    1,403    1,372    1,446    1,396
# 8    경부선 SRT이용률      121      123      121      125      127      125
# 9    호남선 KTX여객수      805      848      865      887      955      895
# 10   호남선 KTX이용률       68       79       74       79       82       79
# 11   호남선 SRT여객수      488      461      493      497      526      503
# 12   호남선 SRT이용률       95      100       96      101      103      102
# ...

# %%
train1=train.loc[0:12]

# %%
train2=train.loc[13:24]

# %%
train3=train.loc[25:29]

# %%
train2 = train2.reset_index(drop=True)

# %%
train3 = train3.reset_index(drop=True)

# %%
train33 = train3.rename(columns=train3.iloc[0])
train33
# Out:
#    202101월  3,640  45   61  1,372  43    709   64  458  41  288  56  281  52  \
# 0  202101월  3,640  45   61  1,372  43    709   64  458  41  288  56  281  52
# 1  202102월  4,213  56   80  1,567  54    883   85  498  54  345  70  315  64
# 2  202103월  5,205  62   97  1,846  59  1,165  103  606  59  458  84  387  73
# 3  202104월  5,370  65  102  1,893  62  1,189  108  638  62  473  90  402  77
# 4  202105월  6,913  70  106  2,102  66  1,293  113  701  66  508  94  437  81
#
#    294  48  238  54
# 0  294  48  238  54
# 1  343  62  272  69
# 2  421  70  322  73
# 3  440  75  335  79
# 4  495  82  375  85

# %%
train3 = train33.rename(columns={'202101월':'월별','3,640':'총 이용객수','45':'KTX 이용률','61':'SRT 이용률'})

# %%
train2 = train22.rename(columns={'202001월':'월별','7,676':'총 이용객수','96':'KTX 이용률','118':'SRT 이용률'})

# %%
train11 = train1.rename(columns=train1.iloc[0])

# %%
train11 = train11.drop([0])

# %%
train1 = train11.rename(columns={'월별':'월별','고속철도 여객수 계':'총 이용객수','KTX이용률':'KTX 이용률','SRT이용률':'SRT 이용률'})

# %%
train11 = train1.rename(columns=train1.iloc[0])

# %%
train1=train11.rename(columns={'201901월':'월별','6,929':'총 이용객수','86':'KTX 이용률','113':'SRT 이용률'})

# %%
train3 = train3.drop(columns=['64','458','41','288','56','281','52','294','48','238','54'], axis=1)

# %%
train2 = train2.drop(columns=['3,055','95','1,449','125','937','82','540','105','589','108','612','105','494','111'], axis=1)

# %%
train1 = train1.drop(columns=['2,822','89','1,366','121','805','68','488','95','499','97','533','93','416','95'], axis=1)

# %%
train1.to_excel('2019철도.xls')

# %%
train2.to_excel('2020철도.xls')

# %%
train3.to_excel('2021철도.xls')
